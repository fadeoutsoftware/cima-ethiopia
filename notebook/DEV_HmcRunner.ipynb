# %%
# SET ENV 
# Base Path /home/continuumuser/workdir 
# %env DOMAIN_NAME='MarcheDomain' 
# %env TIME_RUN="2024-01-01 00:23"
# %env TIME_PERIOD=96
# %env PATH_SRC=/home/continuumuser/workdir/case_study_hmc/
# %env PATH_DST=/home/continuumuser/workdir/case_study_hmc/
# %env PATH_APP=/home/continuumuser/workdir/case_study_hmc/
# %env PATH_LOG=/home/continuumuser/workdir/logs
# %env PATH_NAMELIST=/home/continuumuser/workdir
# %env JSON_PATH=/home/continuumuser/workdir/case_study_hmc/config/app_runner_workflow_hmc_base_MarcheDomain.json
# Out:
# env: DOMAIN_NAME='MarcheDomain'
# env: TIME_RUN="2024-01-01 00:23"
# env: TIME_PERIOD=96
# env: PATH_SRC=/home/continuumuser/workdir/case_study_hmc/
# env: PATH_DST=/home/continuumuser/workdir/case_study_hmc/
# env: PATH_APP=/home/continuumuser/workdir/case_study_hmc/
# env: PATH_LOG=/home/continuumuser/workdir/logs
# env: PATH_NAMELIST=/home/continuumuser/workdir
# env: JSON_PATH=/home/continuumuser/workdir/data/case_study_hmc/config/app_runner_workflow_hmc_base_MarcheDomain.json

# %%
# %run -i '/app/shybox/workflow/runner/app_runner_workflow_hmc_base_main.py' -settings /home/continuumuser/workdir/case_study_hmc/config/app_runner_workflow_hmc_base_MarcheDomain.json
# %pwd
# Out:
# 2025-10-31 12:13:25,597 IPKernelApp  DEBUG
# *** MESSAGE TYPE:execute_request***                                             kernelbase.py:[448    - dispatch_shell      ()]
# 2025-10-31 12:13:25,598 IPKernelApp  DEBUG       Content: {'silent': False, 'store_history': True, 'user_expressions': {}, 'allow_stdin': True, 'stop_on_error': True, 'code': "%run -i '/app/shybox/workflow/runner/app_runner_workflow_hmc_base_main.py' -settings /home/continuumuser/workdir/case_study_hmc/config/app_runner_workflow_hmc_base_MarcheDomain.json\n%pwd"}
#    --->
#     kernelbase.py:[449    - dispatch_shell      ()]
# ...
