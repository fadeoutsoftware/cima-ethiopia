# %%
# SET ENV 
# Base Path /home/continuumuser/workdir 
# %env DOMAIN_NAME='shebele' 
# %env TIME_RUN="2000-01-01 00:23"
# %env TIME_PERIOD=96
# %env PATH_SRC=/home/continuumuser/workdir/case_study_ethiopia/
# %env PATH_DST=/home/continuumuser/workdir/case_study_ethiopia/
# %env PATH_APP=/home/continuumuser/workdir/case_study_ethiopia/
# %env PATH_LOG=/home/continuumuser/workdir/logs
# %env PATH_NAMELIST=/home/continuumuser/workdir
# %env JSON_PATH=/home/continuumuser/workdir/case_study_ethiopia/config/app_runner_workflow_hmc_base.json
# Out:
# 2025-10-31 12:41:32,659 IPKernelApp  DEBUG
# *** MESSAGE TYPE:execute_request***                                             kernelbase.py:[448    - dispatch_shell      ()]
# 2025-10-31 12:41:32,660 IPKernelApp  DEBUG       Content: {'silent': False, 'store_history': True, 'user_expressions': {}, 'allow_stdin': True, 'stop_on_error': True, 'code': '# SET ENV \n# Base Path /home/continuumuser/workdir \n%env DOMAIN_NAME=\'shebele\' \n%env TIME_RUN="2000-01-01 00:23"\n%env TIME_PERIOD=96\n%env PATH_SRC=/home/continuumuser/workdir/case_study_ethiopia/\n%env PATH_DST=/home/continuumuser/workdir/case_study_ethiopia/\n%env PATH_APP=/home/continuumuser/workdir/case_study_ethiopia/\n%env PATH_LOG=/home/continuumuser/workdir/logs\n%env PATH_NAMELIST=/home/continuumuser/workdir\n%env JSON_PATH=/home/continuumuser/workdir/case_study_ethiopia/config/app_runner_workflow_hmc_base.json'}
#    --->
#     kernelbase.py:[449    - dispatch_shell      ()]
# ...

# %%
# %run -i '/app/shybox/workflow/runner/app_runner_workflow_hmc_base_main.py' -settings /home/continuumuser/workdir/case_study_ethiopia/config/app_runner_workflow_hmc_base.json
# %pwd
# Out:
# 2025-10-31 12:41:35,473 IPKernelApp  DEBUG
# *** MESSAGE TYPE:execute_request***                                             kernelbase.py:[448    - dispatch_shell      ()]
# 2025-10-31 12:41:35,474 IPKernelApp  DEBUG       Content: {'silent': False, 'store_history': True, 'user_expressions': {}, 'allow_stdin': True, 'stop_on_error': True, 'code': "%run -i '/app/shybox/workflow/runner/app_runner_workflow_hmc_base_main.py' -settings /home/continuumuser/workdir/case_study_ethiopia/config/app_runner_workflow_hmc_base.json\n%pwd"}
#    --->
#     kernelbase.py:[449    - dispatch_shell      ()]
# ...
